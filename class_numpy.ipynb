# %% [markdown]
# <a href="https://colab.research.google.com/github/xuzijin223-web/wed_2026_bigdatacomputing_class/blob/main/class_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 넘파일 다차원 배열(ndarray) 객체 생성
# - import numpy as np
# - 리스트을 이용하여 다차원 배열 생성
# - np.array(리스트)
#   - 리스트 → 배열로 바꾸고 싶을 때
#   - 단순 저장 → 수학 연산이 필요할 때
#   - 데이터 분석/머신러닝 모델에 데이터를 입력할 때
# - 속성 :
#   - ndim : 배열 축 혹은 차원의 개수
#   - shape : 배열의 형상을 (n, m) 형식의 튜플형으로 표시
#   - size :
#     - 배열 원소의 개수
#     - (m,n) 형상 배열의 size = m*n
#   - dtype : 배열 원소의 자료형을 기술
#   - astype : 배열 원소 형 변환

# %% [markdown]
# # 새 섹션

# %% [markdown]
# # 2. 넘파이 다차원 배열 간 사칙 연산
#   - 피연산자 다차원 배열들의 형상이 같다는 가정
#   - +, -, *, / 연산 수행
#   - 배열 프로그래밍
#   - 선형대수의 벡터화 연산
#   - 벡터을 병렬 연산 수행
#     - 데이터 병렬 처리

# %%
1# 3. 3차원 넘파이 배열을 이용해서 이미지 데이터 기록
2 #3차원 배열은 (asis0, axis1, axis2)axis2)=(깊이,높이,너비)
3 # 디지털 이미지 데이터 (가로, 세로, RGB 채널)
4 # 2*2 크기의 아주 작은 컬러이미지 하나
import numpy as np
tensor_list=[
    [[255,0,0],[0,255,0]],
    [[0,0,255],[255,255,0]]
]
tensor=np,np.array(tensor_list)
print(tensor,nidm) # 3
print(tensor,shape)#(2.2.3)
print (tensor,np.size) # 2*2*3 = 12
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1350/3040455927.py in <cell line: 0>()
#       9 ]
#      10 tensor=np,np.array(tensor_list)
# ---> 11 print(tensor,nidm) # 3
#      12 print(tensor,shape)#(2.2.3)
#      13 print (tensor,np.size) # 2*2*3 = 12
#
# NameError: name 'nidm' is not defined

# %%
# 1차원 배열 사칙연산 -> 1 차원 배열 결과로 반환
# 1차원 넘파이 배열 생성
store_a = [1000, 2000, 1500]
store_b = [2000, 1000, 1000]
arr_a = np.array(store_a)
arr_b = np.array(store_b)
# 형태가 갈은 1차원 배열 간 연산 : (3.)
print(arr_a + arr_b) # [3000 3000 2500]
print(arr_a * arr_b)
print(arr_a - arr_b)
print(arr_a / arr_b)

# %%
# 2차원 배열 사칙 연산 : 동일한 형태을 가지는 배열 (2,3)
arr1_2d = np.array([[1,2,3],
[4,5,6]])
arr2_2d = np.array([[10,20,30], [40,50,60]])
5
6 # 사칙연산
print(arr1_2d + arr2_2d)
print(arr1_2d * arr2_2d)
print(arr1_2d - arr2_2d)
print(arr1_2d / arr2_2d)

# %% [markdown]
# # 3. 넘파이 다차원 배열과 브로드캐스팅
# - 형상이 다른 두 배열 간 사칙연산 수행
#   - 스칼라
#     - 다차원 배열 * 스칼라, 다차원 배열 + 스칼라, 다차원 배열 - 스칼라, 다차원 배열 / 스칼라
#     - 스칼라 + 배열, 스칼라 - 배열, 스칼라 * 배열, 스칼라 /배열
#
#   - 형상이 다른 배열과 사칙 연산
#
# - 브로드캐스팅 이용해서 다차원 배열 프로그래밍
#   - 배열의 차원에 맞게 벡터로 확장하여 동일하게 만듦
#   - 벡터화 연산 * 병렬 처리

# %%
1 # 형상이 서로 다른 배열과 스칼라 간 사칙 연산
import numpy as np
arr_1d = np.array( [1,2,3])
print (arr_1d + 10)
print(arr_1d - 10)
print(arr_1d * 10)
print(arr_1d / 10)
8
9 # 2차원 배열과 1차원 배열 간 사칙 연산 : (2,3), (3)
arr_2d = np.array([[1,2,3],
[4,5,6]])
print(arr_2d + arr_1d)
13
# 2차원 배열과 1차원 배열 간 사칙 연산 불가 : (2,4), (3)
arr_2d = np.array([[1,2,3,4],
[4,5,6,7]])
# print(arr_2d + arr_1d)
18
# 3차원 배열과 2차원 배열 간 사칙 연산  : (3,2,4) , (2,4)
arr_3d = np.array([[[1,2,3,4], [5,6,7,8,5]], [[9,10,11,12,6], [13,14,15,16,5]] , [ [17,18,19,20,7], [21,22,23,24,7] ] ] )
print(arr_3d.shape)
print(arr_2d + arr_3d)

# %% [markdown]
# # 4. 라이브러를 이용하여 연속적인 값을 가지는 다차원 배열 생성
#
# - zeros(n, m)
# - ones(n,m)
# - arange(start, stop, step)
# - linspace(start,stop, num)
# - logspace(start, stop, num)

# %%
import numpy as np
zeros = np.zeros((2,3,4))
print(zeros)
print(zeros.shape, zeros.ndim, zeros.size, zeros.dtype)

# 2. 0~ 10사이의 정수을 가진 1차원 배열을 생성-> 2차원 배열로 변환(2,5)
arr_1d = np.arange (0, 10,1)
print(arr_1d)
print(arr_1d.shape, arr_1d.size)
arr_2d = arr_1d.reshape((2,5))
print(arr_2d)
# 2-1 2차원 배열 (2,4) -- > 오류 발생 -> 해결방법 reshape(2,-1)
# arr_2d = arr_1d.reshape((2,4))
arr_2d_re = arr_1d.reshape((2,-1))
print(arr_2d_re. shape)

# %% [markdown]
# # 5. 다차원 배열을 축을 이용하여 원소를 삽입하여 배열 확장하기
# - np.insert(배열객체, 삽입위치, 삽입 스칼라 값, 삽입할방향)
#   - 1차원 배열에 삽입
#   - 다차원 배열에 삽입
#     - 주어진 배열의 형상을 고려하여 브로드캐스팅 방식

# %%
# insert() 필요성 : 누락된 데이터 포인트를 보간 또는 머신러닝 데이터셋의 특정 열에 새로운 feature(ID, 바이어스)을 삽입
import numpy as np
arr_1d = np.array([10,30,40,50]) # 1d 배열- 20이 누락
# 인덱스 1위치에 숫자 20을 삽입
corrected_data = np.insert(arr_1d,1,20)
print("보정전 :", arr_1d)
print("보정후 :", corrected_data)
8
9 # 2차원 배열에서 열 위치에서 삽입
matrix = np.zeros((2,3))
11 # 1번 열 위치에 [5,5] 삽입
new_matrix = np.insert(matrix, 1,5, axis = 1)
print("보정전 :", matrix)
print("보정후 :", new_matrix)

# %% [markdown]
# # 6. 다차원 배열의 지정된 축 방향으로 원소들을 뒤집기
#   - np.flip(배열객체, axis=)

# %% [markdown]
# # 7. 넘파이 다차원 배열의 인덱싱
# - 다차원 배열의 특정 원소 추출 방식
# - 인덱스 정수을 이용
# - 인덱싱은 두 축을 이용해서 함
#   - axis 0 ; 행 참조
#   - axis 1 ; 열 참조
# - arr[][]
# - arr[,]
# - arr[]

# %% [markdown]
# # 8. 넘파이 다차원 배열의 인덱싱을 이용한 슬라이싱
# - 다차원 배열에서 작은 배열을 추출
# - 인덱싱을 이용하여 슬라이싱 범위 지정
# - 두 축을 이용해서 특정한 행과 열만 별도로 적용하여 추출함
#   - axis 0 ,  axis 1
#   - arr[] ; axis 0 사용
#   - arr[:, :] ;  두 개의 축을 동시에 사용할 때는 쉼표로 구분
#   - arr[: :step] ; axis 0을 이용하여 간격을 두고 추출
#   - arr[::step, ::step]; 두 개의 축을 이용하여 간격을 두고 추출

# %% [markdown]
# # 9.  넘파이 다차원 배열의 슬라이싱을 이용한 논리인덱싱
# - 특정한 조건을 만족하는 배열의 원소값만을 추출하여 1차원 배열 객체로 반환
# - 브로드캐스팅하여 병렬 연산 처리
#
#
# 1. 주어진 배열을 이용하여 조건식을 만족하는 동일한 형상을 가지는 불리언 배열을 생성
#
# 2.   주어진 배열에 불리언 배열을 인덱스로 지정

# %% [markdown]
# # 10. 넘파이의 강력한 기능
# - 다차원 배열의 최대값, 최소값, 평균값 : 벡터화 연산을 이용한 Reduction 기능
#   - arr.max()
#   - arr.min(0
#   - arr.mean()
# - 다차원 배열의 평탄화 기능
#   - arr.flatten()
# - 다차원 배열의 원소의 자료형 변환
#   - arr.astype(np.int64)
#   - arr.astype(np.float64)
#
# - 2차원 배열의 행과 열의 순서 바꾸기
#   -arr.T
#
# - 다차원 배열의 오름차순 정렬
#   - arr.sort()
#   - arr.sort(axis=0)

# %% [markdown]
# # 11. 다차원 배열 생성 ; 기존 배열의 차원과 형태 변환하여 생성
# - 일반적으로 1차원 배열을 생성하여 다차원 배열로 변환
#   - np.arange(start, stop, step)
#
# - 배열의 원소 총개수는 유지
# - np.reshape(튜플형태로 형상 표시)
#   - arr.reshape(n,)
#   - arr.reshape(n,m)
#   - arr.reshape(n, -1)
#   - arr.reshape(n,m,l)
# - np.flatten()
#   - 고차원 배열 -> 1차원 배열 변환

# %% [markdown]
# # 13.난수을 이용한 다차원 배열 만들기
# - random 모듈
#   - rand(개수) - 0과 1사이의 균등분포의 난수 표본을 추출
#   - randn(개수) - 표준정규분포의 난수 표본 추출
#   - randint(최소값,최대값,개수)- 주어진 범위내의 정수 난수 생성. 최대값은 미포함
#   - normal(평균, 표준편차, 개수) - 정규분포의 난수 표본 추출
#   - uniform(개수) - 균등분포에서 표본 추출
#   - shuffle() - 배열를 임의의 순서로 섞는다
#   - permutation() - 배열을 임의의 순서로 섞음

# %% [markdown]
# # 새 섹션

# %%
# 2. 데이터 준비
np. random.seed(42)
scores = np.random. randint (60, 100, 12) . reshape(3, -1) # (3,4)
subjects = ['국어','영어 ', '수학','통계 ']
students = ['영희', '철수','신한']

# 리덕션 연산 : 평균
subject_avg =np.mean(scores, axis = 0).round(2) # 과목별 평균
student_avg = np.mean(scores, axis = 1).round(2) # 학생별 평균

# 3. 복수 개 그래프로 시각화
plt.figure(figsize=(16, 6))
plt.suptitle("원본 데이터 및 리덕션 데이터 분", fontproperties=font_prop, fontslze = 20)
# (1) 원본 데이터 열지도
plt.subplot(1,3,1) # 그래프의 위치
im = plt.imshow(scores, cmap = "YIGnBu")
plt.title("원본 성적 분포", fontproperties=font_prop, fontsize = 15)
plt.xlabel('과목명', fontproperties=font_prop)
plt.ylabel('학생명', fontproperties=font_prop)
plt.xticks(np.arange(len(subjects)), subjects, fontproperties=font_prop
plt.yticks(np.arange(len(students)), students, fontproperties=font_prop
 cbar = plt.colorbar(im)
 cbar.set_label("", fontproperties=font_prop)
38 #(1-1) 특정 좌표에 점수 텍스트을 표기 : plt.text(x,y,str())
39 for i in range(3): # 행 (y축)
for j in range(4): # 열 (x 축)
plt.text(j, i, scores[i, jl, ha="center", va="center", color="black", fontsize=12)
42 # plt.show()
43
44 # (2) 과목별 평균 시각화 : 막대그래프
45 plt.subplot(1,3,2) # 그래프의 위치
46 plt.bar(subjects, subject_avg, color = ['red', 'green', 'blue', 'yellow'], edegecolor = 'black')
47 plt.title("과목별 평균 분포", fontproperties=font_prop, fontsize = 15)
48 plt.xlabel('과목명', fontproperties=font_prop)
49 plt.ylabel('평균점수', fontproperties=font_prop)
50 plt.xticks(np. arange (len(subjects)), subjects, fontproperties=font_prop
for i, score in enumerate(subject_avg): # 막대 상단에 평균 점수 표시

53 plt.show()

plt.text(i, score, str(score), ha="center", va="bottom", color="black", fontsize=12)
# Out:
#   File "/tmp/ipykernel_1350/2465831904.py", line 27
#     plt.text(j, i, scores[i, jl, ha="center", va="center", color="black", fontsize=12)
#                                                                                      ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %% [markdown]
# # 15. 넘파일 배열의 결합
# - np.concatenate(튜플)
# - np.vstack(튜플 또는 리스트)
# - np.hstack(튜플 또는 리스트)
# - np.r_[ 콤마 사용하여 나열 ]
# - np.c_[콤마 사용하여 나열]
# - np.column_stack(리스트)

# %%
1 #----------------
2 # Ex1 1차원 배열간 결합
3 #----------------
4 import numpy as np
5 # 데이터 생성
6 a = np.array( [1,2,3]) # (3,)
7 b = np.array( [4,5,6]) # (3,)
8
9 # 세로 쌓기 (수직방향) -> 행 추가
10 res_stack = np.vstack((a,b))
11
12 # 가로로 붙이기 (수평방향) -> 열 추가해서 1차원 배멸
13 res_hstack = np.hstack((a,b))
14 res_concat = np.concatenate((a,b), axis = 0)
15
16 # 주의 : column_stack() -> 2차원 배열
17 res_col = np.column_stack((a,b))
18

19 #
20 # Ex2 형태가 다른 배열간 결합
21 #
22 arr_1 = np.arange(1,4) #(3,)
23 arr_2 = np.arange(4,10).reshape(2,3) # (2,3)
24 print(arr_1)
25 print()
26 print(arr_2)
27 print()
28 # 방법1
29 # (1) arr_1 -> (1,3) - 열의 개수을 일치
30 arr_1_2d = arr_1.reshape(-1,3)
31 print(arr_1_2d)
32 print()
33 combined_2d = np.concatenate((arr_1_2d, arr_2), axis = 0)
34 print (combined_2d)
35
36 # 방법 2
37 v_combined = np.vstack((arr_1, arr_2))
38 print (v_combined)
39
# Out:
#   File "/tmp/ipykernel_1350/178792275.py", line 4
#     4 import numpy as np
#       ^
# SyntaxError: invalid syntax
